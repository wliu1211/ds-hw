# %% [markdown]
# ## Homework 2

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 1. From df filter the 'Manufacturer', 'Model' and 'Type' for every 20th row starting from 1st (row 0).
# df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
filtered = df[['Manufacturer', 'Model', 'Type']]
twentith = filtered[::20]
twentith
# Out:
#    Manufacturer    Model     Type
# 0         Acura  Integra    Small
# 20     Chrysler  LeBaron  Compact
# 40        Honda  Prelude   Sporty
# 60      Mercury   Cougar  Midsize
# 80       Subaru   Loyale    Small

# %% [markdown]
# #### 2. Replace missing values in Min.Price and Max.Price columns with their respective mean (check documentation).
# df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
df[['Min.Price', 'Max.Price']]
mean_min_price = df['Min.Price'].mean()
mean_max_price = df['Max.Price'].mean()
df['Min.Price'] = df['Min.Price'].fillna(mean_min_price)
df['Max.Price'] = df['Max.Price'].fillna(mean_max_price)

df[['Min.Price', 'Max.Price']]
# Out:
#     Min.Price  Max.Price
# 0   12.900000  18.800000
# 1   29.200000  38.700000
# 2   25.900000  32.300000
# 3   17.118605  44.600000
# 4   17.118605  21.459091
# ..        ...        ...
# 88  16.600000  22.700000
# 89  17.600000  22.400000
# 90  22.900000  23.700000
# 91  21.800000  23.500000
# 92  24.800000  28.500000
#
# [93 rows x 2 columns]

# %% [markdown]
# #### 3. How to get the rows of a dataframe with row sum > 100?
# df = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))

# %%
df = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))
rowSum = df.sum(axis=1)
filteredDf = df[rowSum > 100]
filteredDf
# Out:
#      0   1   2   3
# 7   18  27  32  32
# 8   22  39  18  38
# 12  24  28  19  33

# %% [markdown]
# #### 4. Create a 4x4 NumPy array filled with random integers between 1 and 100. Then, reshape this array into two separate 2D arrays, where one represents the rows and the other represents the columns. Write a function, preferably using a lambda function, to calculate the sum of each row and each column separately, and return the results as two separate NumPy arrays

# %%
array = np.random.randint(1, 100, (4, 4))

addRows = lambda x: np.sum(x, axis=1)
addColumns = lambda x: np.sum(x, axis=0)

rowSums = addRows(array)
columnSums = addColumns(array)

sumDf = pd.DataFrame({
    'Rows' : rowSums,
    'Columns': columnSums
})

sumDf
# Out:
#    Rows  Columns
# 0   302      275
# 1   236      237
# 2   218      261
# 3   243      226
